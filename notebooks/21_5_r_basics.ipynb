# %%
# built-in datasets
data()

# %%
#numeric data types (ints and floats)
?c()

# %%
x <- c(1,2,3)
x
# Out:
# [1] 1 2 3

# %%
x + 2
x - 2
x * 2
x / 2
x ^ 2
x %% 2
# Out:
# [1] 3 4 5
# [1] -1  0  1
# [1] 2 4 6
# [1] 0.5 1.0 1.5
# [1] 1 4 9
# [1] 1 0 1

# %%
# character data types (like strings)
y <- "yo"
y
# Out:
# [1] "yo"

# %%
 paste("Hello")
# Out:
# [1] "Hello"

# %%
# logical (Boolean)
z <- FALSE

# %%
z
# Out:
# [1] FALSE

# %%
x = 5
y = "hello"

x > 2 | y == "world" # or
x > 2 & y == "world" # and
# Out:
# [1] TRUE
# [1] FALSE

# %%
# factors are used to store categorical variables
colors <- factor(c("red", "blue", "green"))

# %%
levels(colors)
# Out:
# [1] "blue"  "green" "red"

# %%
# tabular data type (like DataFrames)
data <- data.frame(x, y, z)

# %%
data
# Out:
#   x y     z
# 1 5 hello FALSE

# %%
# access a specific column with $
data$x
# Out:
# [1] 5

# %%
csv <- "https://raw.githubusercontent.com/BradGroux/programming-for-data-science/main/mock_dataset.csv"

# %%
data <- read.csv(csv)

# %%
data
# Out:
#     id  first_name last_name   email
# 1   235 Lexine     Daouse      ldaouse0@ebay.co.uk
# 2   236 Romonda    Eberlein    reberlein1@angelfire.com
# 3   237 Joanie     Khan        jkhan2@mediafire.com
# 4   238 Joelly     Neising     jneising3@dedecms.com
# 5   239 Wilfrid    Bifield     wbifield4@engadget.com
# 6   240 Nady       Schrir      nschrir5@163.com
# 7   241 Eula       Leinweber   eleinweber6@npr.org
# 8   242 Arnold     Boolsen     aboolsen7@t.co
# 9   243 Roxana     Lenham      rlenham8@google.nl
# 10  244 Eada       Jone        ejone9@tumblr.com
# 11  245 Elsey      Lingwood    elingwooda@a8.net
# 12  246 Kingston   Whyberd     kwhyberdb@vk.com
# 13  247 Jonathon   Britland    jbritlandc@skyrock.com
# 14  248 Gabby      Beebee      gbeebeed@imdb.com
# 15  249 Jsandye    Hidderley   jhidderleye@pagesperso-orange.fr
# 16  250 Romy       Shawe       rshawef@gov.uk
# 17  251 Allina     Barme       abarmeg@quantcast.com
# ...
