# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-pc-linux-gnu"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "linux-gnu"
#
# $system
# [1] "x86_64, linux-gnu"
#
# $status
# [1] ""
#
# $major
# [1] "4"
#
# $minor
# [1] "3.0"
#
# $year
# [1] "2023"
#
# $month
# [1] "04"
#
# $day
# [1] "21"
#
# $`svn rev`
# [1] "84292"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 4.3.0 (2023-04-21)"
#
# $nickname
# [1] "Already Tomorrow"

# %%
print("Hello, world!")
# Out:
# [1] "Hello, world!"

# %%
paste("Hello, world!")
# Out:
# [1] "Hello, world!"
